# %% [markdown]
# n1 = 5, n2 = 9 th = 0.95
#
# Merging Technique on hough lines
# Determine lines on remaining CC of subset 1

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
import math
from sympy import Line, Point, Symbol
from statistics import mean
from sympy.solvers import solve

from Processing import *
from ImageHandler import *
from GeometryProcessing import *
from ImageProcessing import *
from globalVar import *

# %%
rcParams['figure.figsize'] = 7, 14

# %%
image = loadImage('Test-data/050200074.jpg')
plt.imshow(image);

# %%
# Find components and calc avg height of components, assume it equal to avg character width.
# Divide components into 3 subsets based on simple conditions

(labels, avg_height, centroids, stats) = findComponents(image)
((centroids1, stats1), (centroids2, stats2), (centroids3, stats3)) = divide(centroids, stats, avg_height);
# Out:
# 'Found 1569 components with height 19.533460803059274 in image'
# 'Found 745 in subset 1, 5 in subset 2, and 819 in subset 3'

# %%
# Divide subset1 components into blocks of width aw and find their centroid. 

centroidP, mapP = partitionCC(stats1, int (avg_height));

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 28), sharex=True, sharey=True)

ax = axes.ravel()
ax[0].imshow(showCentroids(image, centroids1));
ax[0].set_title('Original', fontsize=20);

ax[1].imshow(showCentroids(image, centroidP));
ax[1].set_title('Partitioned', fontsize=20);

# %%
# Perform Hough transform on this with given parameters.

lines = findHoughLines(showCentroids(image, centroidP), None, avg_height, 100, 10, 40)
init(lines, centroidP);
# Out:
# 'Calculated 52 lines'
# 'Showing...'

# %%
# Make a lookup array mapping partition to its cc
# Check dist of partition from primary line
# Find the CC of that partition from mapping
# If dist of that partition is within +-0.5p then increment value of that CC else decrement
# Discard all CC having +ve value and map to find partition being discarded
# repeat step unless max contri cell < n1
# if n2 > conti > n1, then cell must be within 2 degree from first found cell.

n = 1000;
selLines = [];
while (True):
    lineP, pos, n = findPrimaryCell(lines, centroidP);
    print ("\n Contribution " + str(n), end= " ");
    if n < 5:
        break;
    elif n < 9:
        pTheta = math.radians(selLines[0][1]);
        theta = math.radians(lineP[1]);
        if (not (theta <= pTheta + 2 and theta >= pTheta - 2)):
            continue;
        print ("Low Contribution " + str(n), end = " ");
    
    centroidPN, count = discardPartition(lineP, np.copy(centroidP), centroids1, mapP)
    
    if (count == 0):
        break;
    
    print ("Discarded " + str(count) + " centroids");
    
    centroidP = np.copy(centroidPN);
    selLines.append(lineP);

print ("\n" + str(len(selLines)) + " lines selected");
# Out:
# Checking for line 51 of 51
#  Contribution 36 Discarded 49 centroids
# Checking for line 51 of 51
#  Contribution 32 Discarded 43 centroids
# Checking for line 51 of 51
#  Contribution 31 Discarded 43 centroids
# Checking for line 51 of 51
#  Contribution 30 Discarded 36 centroids
# Checking for line 51 of 51
#  Contribution 28 Discarded 37 centroids
# Checking for line 51 of 51
#  Contribution 27 Discarded 38 centroids
# Checking for line 51 of 51
#  Contribution 26 Discarded 35 centroids
# Checking for line 51 of 51
#  Contribution 26 Discarded 45 centroids
# Checking for line 51 of 51
#  Contribution 26 Discarded 43 centroids
# Checking for line 51 of 51
#  Contribution 25 Discarded 34 centroids
# Checking for line 51 of 51
#  Contribution 25 Discarded 32 centroids
# Checking for line 51 of 51
#  Contribution 25 Discarded 40 centroids
# Checking for line 51 of 51
#  Contribution 25 Discarded 40 centroids
# Checking for line 51 of 51
#  Contribution 25 Discarded 41 centroids
# Checking for line 51 of 51
#  Contribution 24 Discarded 35 centroids
# Checking for line 51 of 51
#  Contribution 24 Discarded 25 centroids
# Checking for line 51 of 51
#  Contribution 24 Discarded 43 centroids
# Checking for line 51 of 51
#  Contribution 24 Discarded 38 centroids
# Checking for line 51 of 51
#  Contribution 23 Discarded 35 centroids
# Checking for line 51 of 51
#  Contribution 23 Discarded 42 centroids
# Checking for line 51 of 51
#  Contribution 23 Discarded 37 centroids
# Checking for line 51 of 51
#  Contribution 22 Discarded 30 centroids
# Checking for line 51 of 51
#  Contribution 19 Discarded 29 centroids
# Checking for line 51 of 51
#  Contribution 18 Discarded 25 centroids
# Checking for line 51 of 51
#  Contribution 17 Discarded 17 centroids
# Checking for line 51 of 51
#  Contribution 17 Discarded 17 centroids
# Checking for line 51 of 51
#  Contribution 14 Discarded 25 centroids
# Checking for line 51 of 51
#  Contribution 13 Discarded 20 centroids
# Checking for line 51 of 51
#  Contribution 11 Discarded 15 centroids
# Checking for line 51 of 51
#  Contribution 11 Discarded 11 centroids
# Checking for line 51 of 51
#  Contribution 11 Discarded 17 centroids
# Checking for line 51 of 51
#  Contribution 11 Discarded 14 centroids
# Checking for line 51 of 51
#  Contribution 10 Discarded 17 centroids
# Checking for line 51 of 51
#  Contribution 10 Discarded 11 centroids
# Checking for line 51 of 51
#  Contribution 10 Discarded 17 centroids
# Checking for line 51 of 51
#  Contribution 10 Discarded 14 centroids
# Checking for line 51 of 51
#  Contribution 8 Low Contribution 8 Discarded 4 centroids
# Checking for line 51 of 51
#  Contribution 8 Low Contribution 8 Discarded 11 centroids
# Checking for line 51 of 51
#  Contribution 7 Low Contribution 7 Discarded 10 centroids
# Checking for line 51 of 51
#  Contribution 7 Low Contribution 7 Discarded 16 centroids
# Checking for line 51 of 51
#  Contribution 7 Low Contribution 7 Discarded 7 centroids
# Checking for line 51 of 51
#  Contribution 6 Low Contribution 6 Discarded 6 centroids
# Checking for line 51 of 51
#  Contribution 5 Low Contribution 5
# 42 lines selected

# %%
def getLine(line):
    rho = line[0]
    theta = line[1]
    a = math.cos(theta)
    b = math.sin(theta)
    x0 = a * rho
    y0 = b * rho
    pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
    pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
    return Line(pt1, pt2);
    
def isAdjacent(linei, linej):
    startLine = Line((0,0),(0,100));
    (_, yi) = linei.intersection(startLine);
    (_, yj) = linej.intersection(startLine);
    
    if abs(yi-yj) < 100:
        return True;
    else:
        return False;

def getIntersections(lines, image):
    (h, w) = np.shape(image);
    Slines = []
    for line in lines:
        Slines.append(getLine(line));
    
    lineProcessed = [];
    distances = [];
    for i in range(len(Slines)):
        lineProcessed.append(i);
        for j in range(len(Slines)):
            if j in lineProcessed:
                continue;
                
            linei = Slines[i];
            linej = Slines[j];
            if isAdjacent(linei, linej):
                inter = linei.intersection(linej);
                distances.append( inter.distance(Point(w/2, inter.y)));
    
    print(distances);
    return mean(distances);

# %%
np.shape(image)
# Out:
# (1602, 1111)

# %%
getIntersections(selLines, image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c53a2341e812> in <module>
# ----> 1 getIntersections(selLines, image)
#
# <ipython-input-23-033fd85e16e3> in getIntersections(lines, image)
#      24     Slines = []
#      25     for line in lines:
# ---> 26         Slines.append(getLine(line));
#      27
#      28     lineProcessed = [];
#
# NameError: name 'getLine' is not defined
